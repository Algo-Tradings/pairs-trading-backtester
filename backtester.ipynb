# %% [markdown]
# <h1>PAIRS TRADING BACKTESTER</h1>

# %% [markdown]
# <h4>The porpouse of this repository is to backtest currencies catched from research</h4>
#
# <quote><i>*If you want to know how Research works, please visit my <a href=https://github.com/Algo-Tradings/pairs-trading-research/blob/main/researcher.ipynb>previous notebook</a> which contains more details.</i></quote>
#
# <quote><i>*If you don't know Pairs Trading yet, please check <a href=https://github.com/Algo-Tradings> my Github profile </a> to know more.</i></quote>
#
# <quote><i>**The backtesting result also generate a file. That way you could use it as you wish, or even in another repos of myself.</i></quote>

# %% [markdown]
# <h3>1. Run Once </h3>
# install necessary packages.
# After that, you need comment the above part of code.

# %%
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install matplotlib==3.2.2
# !{sys.executable} -m pip install sklearn
# !{sys.executable} -m pip install backtrader

# %% [markdown]
# <h3>2. Imports </h3>
# get classes of this system

# %%
# %matplotlib inline
from research import Researcher
from backtester import Backtester

# %% [markdown]
# <h3>3. Researching </h3>
# Retrieve the highest correlated and cointegrated pairs.
# Meaning potential profit for pairs trading strategy

# %%
best_coins = Researcher()
best_coins.load_data()
# best_coins.update_data(timeframe='1d', min_correlation=0.83, interval='1 years ago') # uncomment to update data (may take some time)
best_coins.researched_df
# Out:
#     Currency1  Currency2  Correlation  Cointegration  Criticals     Ratio
# 0    MANAUSDT   SANDUSDT     0.893463      -4.388134  -3.926781  0.849108
# 1     TLMUSDT    SLPUSDT     0.853947      -4.313997  -3.926781  6.883582
# 2   THETAUSDT  ALICEUSDT     0.850621      -4.893424  -3.926781  0.611688
# 3     ENJUSDT   WAXPUSDT     0.848592      -6.670217  -3.926781  5.488810
# 4   ALICEUSDT   BAKEUSDT     0.845557      -4.229541  -3.926781  7.632347
# 5    IOTXUSDT  ALICEUSDT     0.843900      -4.244810  -3.926781  0.015598
# 6    STMXUSDT   WAXPUSDT     0.841175      -6.776812  -3.926781  0.082497
# 7    IOTXUSDT    TLMUSDT     0.841078      -4.826925  -3.926781  1.238508
# 8   THETAUSDT    ENJUSDT     0.837323      -4.622077  -3.926781  2.403433
# 9    IOTAUSDT    ZENUSDT     0.834406      -4.305986  -3.926781  0.019097
# 10   COMPUSDT   AAVEUSDT     0.833715      -4.365774  -3.926781  0.630645
# 11  THETAUSDT   BAKEUSDT     0.830443      -5.276288  -3.926781  4.668612

# %% [markdown]
# <h3>4. Backtesting </h3>
# Get results for each pairs combination.

# %%
backtest = Backtester()
backtest.read_data(best_coins)
backtest.run_backtest()
backtest.backtested_df
# Out:
#    N_trades  Won  Win_rate    Roi  Sharperatio  Drawdown  Currency1  \
# 0        18   11     61.11  10.70         2.84      7.01   MANAUSDT
# 0        47   29     61.70  70.56         1.57      1.71    TLMUSDT
# 0        30   23     76.67  40.81         5.15      0.00  THETAUSDT
# 0        78   47     60.26  79.09         1.39      6.39    ENJUSDT
# 0        64   36     56.25  77.15        10.20      1.45  ALICEUSDT
# 0        25   17     68.00  27.94         3.24      3.43   IOTXUSDT
# 0       137   74     54.01  39.25         1.09     11.95   STMXUSDT
# 0        15    7     46.67 -36.05        -0.60     36.62   IOTXUSDT
# 0        33   23     69.70  56.29         1.83      0.00  THETAUSDT
# 0        34   15     44.12 -14.55        -0.92     26.36   IOTAUSDT
# 0        22   16     72.73   9.71         0.29      2.82   COMPUSDT
# 0        31   14     45.16 -55.25        -0.97     42.45  THETAUSDT
#
#    Currency2     Ratio
# 0   SANDUSDT  0.849108
# 0    SLPUSDT  6.883582
# 0  ALICEUSDT  0.611688
# 0   WAXPUSDT  5.488810
# 0   BAKEUSDT  7.632347
# 0  ALICEUSDT  0.015598
# 0   WAXPUSDT  0.082497
# 0    TLMUSDT  1.238508
# 0    ENJUSDT  2.403433
# 0    ZENUSDT  0.019097
# 0   AAVEUSDT  0.630645
# 0   BAKEUSDT  4.668612

# %% [markdown]
# <h3>4. Try Yourself </h3>
# To see graphical results
# Initial cash is 1000 USD.

# %%
backtest.plot_backtest('MANAUSDT', 'SANDUSDT', 0.850232)
# Out:
# <div id='fe29cb71-d4b6-459a-8891-7b40de68b6ae'></div>

# %% [markdown]
# <h3>5. Considerations</h3>
# In this backtest we clearly saw that some currencies are really interesting to operate. That way pairs trading strategy could give us consistent profits.

# %% [markdown]
# <i>If you want full usage of this backtest, kindly consider visit my others pairs-trading repos.
# For that strategy I have the research, a dashboard and also a 100% autonomous bot</i>
