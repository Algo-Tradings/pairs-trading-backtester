# %%
import numpy as np
from backtesting import Results
import research

# %%
final_df = research.Ratio().get_ratio()
np.vectorize(lambda currency1, currency2, ratio:
                Results().get_and_save_results(currency1,currency2, ratio))(
                    final_df['Currency1'], final_df['Currency2'], final_df['Ratio'])
